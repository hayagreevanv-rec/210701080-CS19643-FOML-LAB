# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn import tree

# %%
data = pd.read_csv("Social_Network_Ads.csv")
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
classifier = DecisionTreeClassifier(criterion ='entropy')
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[64  5]
#  [ 4 27]]
# 0.91

# %%
tree.plot_tree(classifier.fit(X_test, y_test))
# Out:
# [Text(0.3333333333333333, 0.9285714285714286, 'x[0] <= 0.565\nentropy = 0.893\nsamples = 100\nvalue = [69, 31]'),
#  Text(0.16666666666666666, 0.7857142857142857, 'x[1] <= 0.6\nentropy = 0.567\nsamples = 75\nvalue = [65, 10]'),
#  Text(0.08333333333333333, 0.6428571428571429, 'entropy = 0.0\nsamples = 65\nvalue = [65, 0]'),
#  Text(0.25, 0.6428571428571429, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.5, 0.7857142857142857, 'x[1] <= -0.845\nentropy = 0.634\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.4166666666666667, 0.6428571428571429, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5833333333333334, 0.6428571428571429, 'x[1] <= -0.67\nentropy = 0.787\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.5, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6666666666666666, 0.5, 'x[1] <= 1.811\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.5, 0.35714285714285715, 'x[1] <= -0.072\nentropy = 0.391\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.4166666666666667, 0.21428571428571427, 'x[1] <= -0.247\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3333333333333333, 0.07142857142857142, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5, 0.07142857142857142, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5833333333333334, 0.21428571428571427, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8333333333333334, 0.35714285714285715, 'x[0] <= 0.991\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.75, 0.21428571428571427, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9166666666666666, 0.21428571428571427, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
tree.plot_tree(classifier.fit(X_test, y_pred))
# Out:
# [Text(0.6, 0.9444444444444444, 'x[1] <= 0.6\nentropy = 0.904\nsamples = 100\nvalue = [68, 32]'),
#  Text(0.3333333333333333, 0.8333333333333334, 'x[0] <= 0.565\nentropy = 0.707\nsamples = 83\nvalue = [67, 16]'),
#  Text(0.13333333333333333, 0.7222222222222222, 'x[1] <= 0.016\nentropy = 0.27\nsamples = 65\nvalue = [62, 3]'),
#  Text(0.06666666666666667, 0.6111111111111112, 'entropy = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.2, 0.6111111111111112, 'x[1] <= 0.104\nentropy = 0.592\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.13333333333333333, 0.5, 'x[0] <= -0.381\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.06666666666666667, 0.3888888888888889, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2, 0.3888888888888889, 'x[0] <= 0.234\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.13333333333333333, 0.2777777777777778, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.26666666666666666, 0.2777777777777778, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.26666666666666666, 0.5, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.5333333333333333, 0.7222222222222222, 'x[0] <= 1.227\nentropy = 0.852\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.4666666666666667, 0.6111111111111112, 'x[1] <= -1.327\nentropy = 0.961\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.4, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5333333333333333, 0.5, 'x[0] <= 0.991\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.4666666666666667, 0.3888888888888889, 'x[1] <= -1.035\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.4, 0.2777777777777778, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5333333333333333, 0.2777777777777778, 'x[1] <= -0.757\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.4, 0.16666666666666666, 'x[0] <= 0.802\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3333333333333333, 0.05555555555555555, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4666666666666667, 0.05555555555555555, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6666666666666666, 0.16666666666666666, 'x[0] <= 0.802\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.6, 0.05555555555555555, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7333333333333333, 0.05555555555555555, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.6, 0.3888888888888889, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.6111111111111112, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8666666666666667, 0.8333333333333334, 'x[1] <= 1.358\nentropy = 0.323\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.8, 0.7222222222222222, 'x[1] <= 1.183\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7333333333333333, 0.6111111111111112, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8666666666666667, 0.6111111111111112, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9333333333333333, 0.7222222222222222, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]')]

# %% [markdown]
# https://www.kaggle.com/code/alirezahasannejad/decision-tree-classifier-tutorial
